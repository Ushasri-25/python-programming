# %% [markdown]
# # Data Types

# %% [markdown]
# Data type represent the type of data present inside a variable.

# %% [markdown]
# In python we are not required to specify the type explicity.

# %% [markdown]
# Based on value provided., the type will be assigned automatically.

# %% [raw]
# i.e. dynamically typed language.

# %%
a=20
print(type(a))
# Out:
# <class 'int'>

# %% [markdown]
# # Number of Data Types in python

# %% [markdown]
# 1. int ->numbers(...,-2,-1,0,1,2,...)
# 2. float ->decimal value
# 3. complex ->real+imaginary values(6+8j)
# 4. str ->character or group of characters
# 5. bool ->True/False

# %% [markdown]
# # Composite Data Types

# %% [markdown]
# 1. Bytes = 0-255(256)
# 2. Bytearray = formate will change
# 3. range
# 4. List
# 5. Tuple
# 6. Set
# 7. Frozonset
# 8. Dictionary
# 9. None

# %% [markdown]
# # int Data Type

# %%
total=100
abc=200
print(total)
print(type(abc))
# Out:
# 100
# <class 'int'>

# %% [markdown]
# # We can represent int in multiple format

# %% [markdown]
# <!-- 1.Binary - base:2
# 2.Decimal - base:10
# 3.Octal  - base:8
# 4.Hexadecimal - base:16 -->

# %% [markdown]
# 1. Binary = base:2
# 2. Decimal = base:10
# 3. Octal = base:8
# 4. Hexadecimal = base:16

# %% [markdown]
# # Binary to all

# %%
b=0b11111111
b,oct(b),hex(b)
# Out:
# (255, '0o377', '0xff')

# %% [markdown]
# # Octal to all

# %%
c=0o2435
c,bin(c),hex(c)
# Out:
# (1309, '0b10100011101', '0x51d')

# %% [markdown]
# # Hex to all

# %%
d=0xAB345
d,bin(d),oct(d)
# Out:
# (701253, '0b10101011001101000101', '0o2531505')

# %% [markdown]
# # Decimal to all

# %%
a=1000
a,bin(a),oct(a),hex(a)
# Out:
# (1000, '0b1111101000', '0o1750', '0x3e8')

# %% [markdown]
# # Float

# %%
a =10.69
print(a)
print(type(a))
# Out:
# 10.69
# <class 'float'>

# %% [markdown]
# # complex

# %%
x=6+10j
print(x)
print(type(x))
# Out:
# (6+10j)
# <class 'complex'>

# %%
x.real
# Out:
# 6.0

# %%
x.imags
# Out:
# 10.0

# %%
name= 'python'
name2="vivan"
print(name2)
print(type(name2))
# Out:
# vivan
# <class 'str'>

# %%
my_name='''Nihan'''
print(my_name)
# Out:
# Nihan

# %% [markdown]
# # writting comment in python

# %% [markdown]
# 1. using 'commnet' you can write comment
# 2. using 'comment' you can write comment single line
# 3.using "comment" you can write comment in single line
# 4. using '''comment''' you can comment in multiline

# %% [markdown]
# # Bool

# %%
a=True
print(a)
print(type(a))
# Out:
# True
# <class 'bool'>

# %%
x=False
print(x)
print(type(x))
# Out:
# False
# <class 'bool'>

# %%
x=30
y=50
print(x is y)
# Out:
# False

# %%
p=100
r=100
print(p is r)
# Out:
# True

# %%
id(a)
id(b)
# Out:
# 140720144696168
