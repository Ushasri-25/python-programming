# %% [raw]
# 1. For running the programm we need a software know compiler or interpreter
# 2. For writing the program we need IDE.(pycharm)

# %% [raw]
# Code==>IDE==>Interpreter/compiler==>Byte_code==>PVM==>Output==>IDE

# %% [markdown]
# # python

# %%
'''Python is a general purpose programming language.
ex : solving program , Automate
Python is a High level programming alanguage.
Developed by Guido Van Rossam in 1989 , Working National Institute at Netherlamnd.
But officailly python was launched in Feb 20 ,1991.
This is the first programming language for beginners'''
# Out:
# 'Python is a general purpose programming language.\nex : solving program , Automate\nPython is a High level programming alanguage.\nDeveloped by Guido Van Rossam in 1989 , Working National Institute at Netherlamnd.\nBut officailly python was launched in Feb 20 ,1991.\nThis is the first programming language for beginners'

# %%
print(" Hello World")
# Out:
#  Hello World

# %%
a=10
b=20
c=a+b
print("Addition :",c)
# Out:
# Addition : 30

# %% [markdown]
# # How Guido has written the python

# %% [markdown]
# 1. Functional programming features from c.
# 2. objects oriented programming features from c++.
# 3. Scripting language feature from per1 and shell.
# 4. Modular programming from module-3
# 5. Most of the syntax from c and ABC

# %% [markdown]
# # Features of python

# %% [markdown]
# 1. python is simple and easy.
# 2. Freeware and open source.
# 3. High level programming
# 4. Platform Independent
# 5. Python is portable
# 6. Dynamically Typed Language
# 7. procedure Oriented "c" and object oriented "c++"
# 8. Python is Interpreted language.
# 9. Extensible (with python you can use other language)
# 10. Embedded
# 11. Python is Extensive library.

# %% [markdown]
# # Flavours of python

# %% [markdown]
# 1. c + python = Cpython
# 2. C + python = Cython
# 3. Java + Python = Jython
# 4. Python + python =pypython
# 5. Anacaonda + Python = Anacondapython

# %% [markdown]
# # Versions of python

# %% [markdown]
# 1. python 1.0 v -Jan 1994
# 2. python 2.0 v -Oct 2000
# 3. python 3.0 v -Dec 2008
